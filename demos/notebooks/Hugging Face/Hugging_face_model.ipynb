# %%
import mlflow

# %%
mlflow.set_tracking_uri(f"http://model-platform.com/registry/grosse-conf-25/")

# %%
import pandas as pd
import mlflow.pyfunc
from transformers import pipeline

model = pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english")


class HFModelWrapper(mlflow.pyfunc.PythonModel):
    def load_context(self, context):
        self.model = pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english")

    def predict(self, model_input):
        if isinstance(model_input, dict):
            input_df = pd.DataFrame([model_input])
        else:
            input_df = pd.DataFrame(model_input)
        return self.model(input_df.iloc[:, 0].tolist())


mlflow.pyfunc.log_model(python_model=HFModelWrapper(), artifact_path="custom_model",
                        registered_model_name="huggingface_model")

# %%
from huggingface_hub import HfApi
api = HfApi()
models = api.list_models(search="distilbert-base-uncased-finetuned-sst-2-english")

# %%
[next(models) for _ in range(10)]
# Out:
# [ModelInfo(id='distilbert/distilbert-base-uncased-finetuned-sst-2-english', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 4, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=6808386, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=717, library_name='transformers', tags=['transformers', 'pytorch', 'tf', 'rust', 'onnx', 'safetensors', 'distilbert', 'text-classification', 'en', 'dataset:sst2', 'dataset:glue', 'arxiv:1910.01108', 'doi:10.57967/hf/0181', 'license:apache-2.0', 'model-index', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=6, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Xenova/distilbert-base-uncased-finetuned-sst-2-english', author=None, sha=None, created_at=datetime.datetime(2023, 5, 2, 21, 19, 47, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=8976, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=10, library_name='transformers.js', tags=['transformers.js', 'onnx', 'distilbert', 'text-classification', 'base_model:distilbert/distilbert-base-uncased-finetuned-sst-2-english', 'base_model:quantized:distilbert/distilbert-base-uncased-finetuned-sst-2-english', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=1, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='ali2066/distilbert-base-uncased-finetuned-sst-2-english-finetuned-argmining', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=118, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=0, library_name='transformers', tags=['transformers', 'pytorch', 'tensorboard', 'distilbert', 'text-classification', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=0, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='ali2066/distilbert-base-uncased-finetuned-sst-2-english-finetuned-argumentative', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=119, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=0, library_name='transformers', tags=['transformers', 'pytorch', 'tensorboard', 'distilbert', 'token-classification', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='token-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=0, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='ali2066/distilbert-base-uncased-finetuned-sst-2-english_token_itr0_2e-05_all_01_03_2022-04_11_31', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=0, library_name=None, tags=['region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=0, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='kapilchauhan/distilbert-base-uncased-finetuned-sst-2-english-finetuned-cola', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=0, library_name=None, tags=['region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=0, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='kurianbenoy/distilbert-base-uncased-finetuned-sst-2-english-finetuned-imdb', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=131, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=0, library_name='transformers', tags=['transformers', 'pytorch', 'tensorboard', 'distilbert', 'text-classification', 'generated_from_trainer', 'dataset:imdb', 'license:apache-2.0', 'model-index', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=0, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='sshleifer/tiny-distilbert-base-uncased-finetuned-sst-2-english', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=131, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=0, library_name='transformers', tags=['transformers', 'pytorch', 'tf', 'distilbert', 'text-classification', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=0, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='juns/imdb_finetuned_distilbert-base-uncased-finetuned-sst-2-english', author=None, sha=None, created_at=datetime.datetime(2022, 3, 18, 7, 5, 6, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=20, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=0, library_name='transformers', tags=['transformers', 'pytorch', 'distilbert', 'text-classification', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=0, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='optimum/distilbert-base-uncased-finetuned-sst-2-english', author=None, sha=None, created_at=datetime.datetime(2022, 3, 24, 16, 6, 17, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=12378, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=2, library_name='transformers', tags=['transformers', 'onnx', 'text-classification', 'en', 'dataset:sst2', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=0, siblings=None, spaces=None, safetensors=None, security_repo_status=None)]

# %%
next(models)

# %%
all_models = [m for m in models]

# %%
len(all_models)
# Out:
# 86

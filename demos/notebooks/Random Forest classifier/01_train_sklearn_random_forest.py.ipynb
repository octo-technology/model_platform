# %% [markdown]
# # Random Forest classifier

# %%
import mlflow.sklearn
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Modèle de classification de données IRIS avec Random Forest Sklearn

# %% [markdown]
# Chargement des données

# %%
data = load_iris()
x = data.data
y = data.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Définition sure serveur MLFLOW

# %%
mlflow.set_tracking_uri(f"<INSERT REGISTRY URI>")
mlflow.set_tracking_uri(f"http://model-platform.com/registry/manoirgressy")

# %% [markdown]
# ### Entrainement du modèle et versioning dans MLFLOW avec sa model card

# %%
with mlflow.start_run():
    model = RandomForestClassifier(n_estimators=10, random_state=42)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    mlflow.log_metric("accuracy", accuracy)
    mlflow.sklearn.log_model(model, "custom_model", registered_model_name="random_forest_iris_classifier")
    model_card = open("model_card.md", "r").read()
    mlflow.set_tag("mlflow.note.content", model_card)
    print(f"Model Accuracy: {accuracy}")
    print("Model saved to MLflow!")
# Out:
# 2025/04/09 16:35:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'random_forest_iris_classifier' already exists. Creating a new version of this model...
# 2025/04/09 16:35:25 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: random_forest_iris_classifier, version 2
# Model Accuracy: 1.0
# Model saved to MLflow!
# 🏃 View run clumsy-grouse-49 at: http://model-platform.com/registry/manoirgressy/#/experiments/0/runs/2e8d4f8e6c834699bcc8528667a0c3a0
# 🧪 View experiment at: http://model-platform.com/registry/manoirgressy/#/experiments/0
# Created version '2' of model 'random_forest_iris_classifier'.
